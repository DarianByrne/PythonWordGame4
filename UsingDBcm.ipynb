# %%
import DBcm

# %%
creds = {
    "user": "wordgame4user",
    "password": "wordgame4passwd",
    "host": "localhost",
    "database": "wordgame4DB",
}

# %%
with DBcm.UseDatabase(creds) as db:
    SQL = "describe leaderboard"
    db.execute(SQL)
    res = db.fetchall()
res
# Out:
# [('time', 'decimal(10,0)', 'YES', '', None, ''),
#  ('who', 'varchar(64)', 'YES', '', None, ''),
#  ('sourceword', 'varchar(64)', 'YES', '', None, ''),
#  ('matches', 'varchar(256)', 'YES', '', None, '')]

# %%
type(res)
# Out:
# list

# %%
res
# Out:
# [('time', 'decimal(10,0)', 'YES', '', None, ''),
#  ('who', 'varchar(64)', 'YES', '', None, ''),
#  ('sourceword', 'varchar(64)', 'YES', '', None, ''),
#  ('matches', 'varchar(256)', 'YES', '', None, '')]

# %%
for line in res:
    print(line)
    print("-"*40)
# Out:
# ('time', 'decimal(10,0)', 'YES', '', None, '')
# ----------------------------------------
# ('who', 'varchar(64)', 'YES', '', None, '')
# ----------------------------------------
# ('sourceword', 'varchar(64)', 'YES', '', None, '')
# ----------------------------------------
# ('matches', 'varchar(256)', 'YES', '', None, '')
# ----------------------------------------
